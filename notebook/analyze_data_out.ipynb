# %%
# %cd ~/dagshub-demo/
# Out:
# /home/khuyen/dagshub-demo

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize

# %%
figsize(10, 10)

# %%
df = pd.read_csv("data/final/segmented.csv")

# %%
df.columns
# Out:
# Index(['Income', 'Recency', 'NumWebVisitsMonth', 'Complain', 'age',
#        'total_purchases', 'enrollment_years', 'family_size', 'clusters'],
#       dtype='object')

# %%
def create_box_plot(df: pd.DataFrame, y: str):
    sorted_clusters = (
        df.groupby(["clusters"]).agg({y: "median"}).sort_values(by=y).index
    )
    sns.boxplot(data=df, x="clusters", y=y, order=sorted_clusters)
    plt.plot()

# %%
columns = ["Income", "NumWebVisitsMonth", "age", "total_purchases", "family_size"]

# %%
# Parameters
columns = [
    "Income",
    "Recency",
    "NumWebVisitsMonth",
    "Complain",
    "age",
    "total_purchases",
    "enrollment_years",
    "family_size",
]

# %%
for col in columns:
    create_box_plot(df, col)
    plt.plot()
    plt.show()
